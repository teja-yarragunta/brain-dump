# %%
print('python101 - Enumerate')
friends = ['Brian', 'Judith', 'Reg', 'Loretta', 'Colin']

i = 1
for friend in friends:
    print(i, friend)
    i = i +1 # += 1
# Out:
# python101 - Enumerate
# 1 Brian
# 2 Judith
# 3 Reg
# 4 Loretta
# 5 Colin

# %%
for num, friend in enumerate(friends):
    print(num, friend)
# Out:
# 0 Brian
# 1 Judith
# 2 Reg
# 3 Loretta
# 4 Colin

# %%
for num, friend in enumerate(friends,1):
    print(num, friend)
# Out:
# 1 Brian
# 2 Judith
# 3 Reg
# 4 Loretta
# 5 Colin

# %%
for num, friend in enumerate(friends,51):
    print(num, friend)
# Out:
# 51 Brian
# 52 Judith
# 53 Reg
# 54 Loretta
# 55 Colin

# %%
# this is what the enumerator does
enumerated_friends = [(51,'Brian'), (52,'Judith'), (53,'Reg'), (54,'Loretta'), (55,'Colin')]
# converts to list of tuples

# %%
for num, friend in enumerate(friends,51):
    print(num, friend)
    
print(type(enumerate(friends)))
print(list(enumerate(friends)))
# Out:
# 51 Brian
# 52 Judith
# 53 Reg
# 54 Loretta
# 55 Colin
# <class 'enumerate'>
# [(0, 'Brian'), (1, 'Judith'), (2, 'Reg'), (3, 'Loretta'), (4, 'Colin')]

# %%
for num, friend in enumerate(friends,51):
    print(num, friend)
for friend in enumerate(friends,51):
    print(friend)
    
print(type(enumerate(friends)))
print(list(enumerate(friends)))
# Out:
# 51 Brian
# 52 Judith
# 53 Reg
# 54 Loretta
# 55 Colin
# (51, 'Brian')
# (52, 'Judith')
# (53, 'Reg')
# (54, 'Loretta')
# (55, 'Colin')
# <class 'enumerate'>
# [(0, 'Brian'), (1, 'Judith'), (2, 'Reg'), (3, 'Loretta'), (4, 'Colin')]

# %%
for num, friend in enumerate(friends,51):
    print(num, friend)
for friend in enumerate(friends,51):
    print(friend)
for friend in enumerate(enumerate(friends,51),-100):
    print(friend)   
print(type(enumerate(friends)))
print(list(enumerate(friends)))
# Out:
# 51 Brian
# 52 Judith
# 53 Reg
# 54 Loretta
# 55 Colin
# (51, 'Brian')
# (52, 'Judith')
# (53, 'Reg')
# (54, 'Loretta')
# (55, 'Colin')
# (-100, (51, 'Brian'))
# (-99, (52, 'Judith'))
# (-98, (53, 'Reg'))
# (-97, (54, 'Loretta'))
# (-96, (55, 'Colin'))
# <class 'enumerate'>
# [(0, 'Brian'), (1, 'Judith'), (2, 'Reg'), (3, 'Loretta'), (4, 'Colin')]

# %%
# we can use enumerate in lists, tuples and strings, not so much in dictionaries and sets because they are not sequences
for num, friend in enumerate(friends,51):
    print(num, friend)
for friend in enumerate(friends,51):
    print(friend)
for friend in enumerate(enumerate(friends,51),-100):
    print(friend)   
for num, letter in enumerate('python',start = 5):
    print(num, letter)
print(type(enumerate(friends)))
print(list(enumerate(friends)))
# Out:
# 51 Brian
# 52 Judith
# 53 Reg
# 54 Loretta
# 55 Colin
# (51, 'Brian')
# (52, 'Judith')
# (53, 'Reg')
# (54, 'Loretta')
# (55, 'Colin')
# (-100, (51, 'Brian'))
# (-99, (52, 'Judith'))
# (-98, (53, 'Reg'))
# (-97, (54, 'Loretta'))
# (-96, (55, 'Colin'))
# 5 p
# 6 y
# 7 t
# 8 h
# 9 o
# 10 n
# <class 'enumerate'>
# [(0, 'Brian'), (1, 'Judith'), (2, 'Reg'), (3, 'Loretta'), (4, 'Colin')]

# %%
my_list = [1,5,3,7,2]
my_dict = {'car':4,'dog':2,'add':3,'bee':1}
my_tuple = ('d','c','e','a','b')
my_string = 'python'

# %%
# print(my_list,'original')
# print(my_list.sort()) # just does the sorting work
# print(my_list,'new')
# Out:
# [1, 5, 3, 7, 2] original
# None
# [1, 2, 3, 5, 7] new

# %%
# print(my_list,'original')
# print(my_list.reverse())
# print(my_list,'new')
# Out:
# [1, 2, 3, 5, 7] original
# None
# [7, 5, 3, 2, 1] new

# %%
print(my_list,'original')
print(sorted(my_list)) # just sorts and gives, no storing
print(my_list,'new')
# Out:
# [1, 5, 3, 7, 2] original
# [1, 2, 3, 5, 7]
# [1, 5, 3, 7, 2] new

# %%
list1 = [1,5,6,32,0]
list2 = sorted(list1)
print(list1)
print(list2)
# Out:
# [1, 5, 6, 32, 0]
# [0, 1, 5, 6, 32]

# %%
print(my_tuple,'original')
print(sorted(my_tuple)) # getting a list
print(my_tuple,'new')
# Out:
# ('d', 'c', 'e', 'a', 'b') original
# ['a', 'b', 'c', 'd', 'e']
# ('d', 'c', 'e', 'a', 'b') new

# %%
print(my_string,'original')
print(sorted(my_string)) # list
print(my_string,'new')
# Out:
# python original
# ['h', 'n', 'o', 'p', 't', 'y']
# python new

# %%
print(my_dict,'original')
print(sorted(my_dict)) # a list but sorted only key values
print(my_dict,'new')
# Out:
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} original
# ['add', 'bee', 'car', 'dog']
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} new

# %%
print(my_dict,'original')
print(sorted(my_dict.items())) # list of tuples
print(my_dict,'new')
# Out:
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} original
# [('add', 3), ('bee', 1), ('car', 4), ('dog', 2)]
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} new

# %%
print(my_dict,'original')
print(sorted(my_dict.values()))
print(my_dict,'new')
# Out:
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} original
# [1, 2, 3, 4]
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} new

# %%
print(my_dict,'original')
print(sorted(my_dict.values(), reverse=True))
print(my_dict,'new')
# Out:
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} original
# [4, 3, 2, 1]
# {'car': 4, 'dog': 2, 'add': 3, 'bee': 1} new

# %%
my_list = [1,5,3,7,2]
print(my_list,'original')
print(list(reversed(my_list)))
print(my_list,'new')
# Out:
# [1, 5, 3, 7, 2] original
# [2, 7, 3, 5, 1]
# [1, 5, 3, 7, 2] new

# %%
print(my_list[::-1]) # reverse
# Out:
# [2, 7, 3, 5, 1]

# %%
my_list = [1,5,-3,7,-2]
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
print(sorted(my_list))
# Out:
# [-3, -2, 1, 5, 7]

# %%
my_list = [1,5,-3,7,-2]
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
print(sorted(my_list, key = abs))
# Out:
# [1, -2, -3, 5, 7]

# %%
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
print(sorted(my_llist)) # by first element - here its string
# Out:
# [['add', 3, 10], ['bee', 1, 24], ['car', 4, 65], ['dog', 2, 30]]

# %%
my_list = [1,5,-3,7,-2]
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
print(sorted(my_llist, key = lambda item :item[1]))
# Out:
# [['bee', 1, 24], ['dog', 2, 30], ['add', 3, 10], ['car', 4, 65]]

# %%
my_list = [1,5,-3,7,-2]
my_llist=[['car',4,65],['dog',2,30],['add',3,10],['bee',1,24]]
print(sorted(my_llist, key = lambda item :item[2]))
# Out:
# [['add', 3, 10], ['bee', 1, 24], ['dog', 2, 30], ['car', 4, 65]]

# %%
# 🛂 Access Control Scanner Challenge
#
# 1. Create a set of revoked badge numbers.
# 2. Create two empty lists: "approved" and "denied".
# 3. Start a loop to collect visitor info:
#    - Ask for the visitor's name (or type "done" to finish).
#    - If the name is "done", exit the loop.
#    - Otherwise, ask for their badge number.
#    - Check if the badge is revoked:
#        • If revoked: add the name to "denied" and display "ACCESS DENIED".
#        • If not: add the name to "approved" and display "ACCESS GRANTED".
# 4. Print the final "Access Summary" for "✅ Approved Visitors" & "⛔️ Denied Visitors":
#    - Sort both lists alphabetically.
#    - Display the total number of approved and denied visitors.

# %%
revoked_badges = {"X123", "B789", "Z999"}

approved = []
denied = []

while True:
  name = input("Enter person's name (or type 'done' to finish): ")
  if name.lower() == "done":
    break

  badge = input("Enter badge number: ").strip().upper()

  if badge in revoked_badges:
    denied.append(name)
    print(f"[ACCESS DENIED] {name} - Revoked badge")
  else:
    approved.append(name)
    print(f"[ACCESS GRANTED] {name}")

print("===== Access Summary =====")

print("✅ Approved Visitors:")
for person in sorted(approved):
  print(f" - {person}")

print("⛔️ Denied Visitors:")
for person in sorted(denied):
  print(f" - {person}")

print(f"Total Approved: {len(approved)}")
print(f"Total Denied: {len(denied)}")
# Out:
# [ACCESS GRANTED] teja
# [ACCESS DENIED] zoro - Revoked badge
# [ACCESS DENIED] luffy - Revoked badge
# [ACCESS DENIED] nami - Revoked badge
# [ACCESS GRANTED] goku
# [ACCESS GRANTED] jesus
# ===== Access Summary =====
# ✅ Approved Visitors:
#  - goku
#  - jesus
#  - teja
# ⛔️ Denied Visitors:
#  - luffy
#  - nami
#  - zoro
# Total Approved: 3
# Total Denied: 3

# %%
# ☕️ Loyalty Points Engine Challenge
#
# RULES:
# • Each whole dollar spent earns 3 points
# • Tiers:
#     < 100 pts   →  Bronze
#     100-499 pts → Silver
#     ≥ 500 pts   →  Gold
#
# STEPS:
# 1. Define earn_points(price) → returns points for one purchase
# 2. Define tier_label(points) → returns "Bronze" / "Silver" / "Gold"
# 3. Given the hard-coded list `purchases`,
#    loop through it, call earn_points() for each amount,
#    and add the result to total_points.
# 4. After the loop, call tier_label(total_points)
# 5. Print 'Loyalty Summary':
#       • Total dollars spent
#       • Total points earned
#       • Final tier

# Purchase history (e.g., 3.75, 7.20, etc.)

# %%
purchases = [12.50, 34.20, 299.99]

def earn_points(price):
    """
    Convert a purchase amount into whole-dollar points.
    Each dollar = 3 pts. Fractions of a dollar are ignored.
    """
    whole_dollar = int(price)
    return whole_dollar * 3
    
def tier_label(points):
    """Return the loyalty tier name based on total points."""
    if points >= 500:
        return "Gold"
    elif points >= 100:
        return "Silver"
    else:
        return "Bronze"
        
total_spent = 0.0
total_points = 0

for amount in purchases:
    total_spent += amount
    total_points += earn_points(amount)
    
final_tier = tier_label(total_points)

print("===== Loyalty Summary =====")
print(f"Total spent: ${total_spent:.2f}")
print(f"Total points: {total_points}")
print(f"Tier achieved: {final_tier}")
# Out:
# ===== Loyalty Summary =====
# Total spent: $1.99
# Total points: 3
# Tier achieved: Bronze

# %%
purchases = [1.00]

def earn_points(price):
    """
    Convert a purchase amount into whole-dollar points.
    Each dollar = 3 pts. Fractions of a dollar are ignored.
    """
    whole_dollar = int(price)
    return whole_dollar * 3
    
def tier_label(points):
    """Return the loyalty tier name based on total points."""
    if points >= 500:
        return "Gold"
    elif points >= 100:
        return "Silver"
    else:
        return "Bronze"
        
total_spent = 0.0
total_points = 0

for amount in purchases:
    total_spent += amount
    total_points += earn_points(amount)
    
final_tier = tier_label(total_points)

print("===== Loyalty Summary =====")
print(f"Total spent: ${total_spent:.2f}")
print(f"Total points: {total_points}")
print(f"Tier achieved: {final_tier}")
# Out:
# ===== Loyalty Summary =====
# Total spent: $1.00
# Total points: 3
# Tier achieved: Bronze
