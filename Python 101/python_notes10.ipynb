# %%
# error handling

print("Errors: Try/Except")

#try:
    #code you want to run
#except:
    #executed if error occurs
#else:
    #executed if no error
#finally:
    #always executed
# Out:
# Errors: Try/Except

# %%
num=int(input('Enter a number: '))
print("30 divided by",num, "is: ", 30/num)
print("**Thank you for playing!**")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 num=int(input('Enter a number: '))
# ----> 2 print("30 divided by",num, "is: ", 30/num)
#       3 print("**Thank you for playing!**")
#
# ZeroDivisionError: division by zero

# %%
try:
    num=int(input('Enter a number: '))
    print("30 divided by",num, "is: ", 30/num)
except:
    print("Invalid Input!")
print("**Thank you for playing!**")
# Out:
# 30 divided by 3 is:  10.0
# **Thank you for playing!**

# %%
try:
    num=int(input('Enter a number: '))
    print("30 divided by",num, "is: ", 30/num)
except ValueError:
    print("Bad Value!")
    
except:
    print("Invalid Input!")
print("**Thank you for playing!**")
# Out:
# Bad Value!
# **Thank you for playing!**

# %%
try:
    num=int(input('Enter a number: '))
    print("30 divided by",num, "is: ", 30/num)
except ZeroDivisionError:
    print("You can't divide by Zero!!!")
except ValueError:
    print("Bad Value!")
except:
    print("Invalid Input!")
print("**Thank you for playing!**")
# Out:
# You can't divide by Zero!!!
# **Thank you for playing!**

# %%
try:
    num=int(input('Enter a number: '))
    print("30 divided by",num, "is: ", 30/num)
except ZeroDivisionError as err:
    print(err, "You can't divide by Zero!!!")
except ValueError as err:
    print(err, "Bad Value!")
except:
    print("Invalid Input!")
print("**Thank you for playing!**")
# Out:
# invalid literal for int() with base 10: 'd' Bad Value!
# **Thank you for playing!**

# %%
try:
    num=int(input('Enter a number: '))
    print("30 divided by",num, "is: ", 30/num)
except ZeroDivisionError as err:
    print(err, "You can't divide by Zero!!!")
except ValueError as err:
    print(err, "Bad Value!")
except:
    print("Invalid Input!")
print("**Thank you for playing!**")
# Out:
# 30 divided by 6 is:  5.0
# **Thank you for playing!**

# %%
try:
    num=int(input('Enter a number between 1 and 30: '))
    num1 = 30/num
    if num > 30:
        raise ValueError(num)
except ZeroDivisionError as err:
    print(err, "You can't divide by Zero!!!")
except ValueError as err:
    print(err,num, "Bad Value not between 1 and 30!")
except:
    print("Invalid Input!")
else:
    print("30 divided by",num, "is: ", 30/num)
finally:
    print("**Thank you for playing!**")
# Out:
# 30 divided by 8 is:  3.75
# **Thank you for playing!**
