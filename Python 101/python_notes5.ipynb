# %%
# functions
# always declare them before using them

# %%
def greeting():
    print("hello friend!")

greeting()
# Out:
# hello friend!

# %%
def greeting(name):
    print("Hello " + name + "!")
    
greeting("Brian")
# Out:
# Hello Brian!

# %%
def greeting(name,age):
    print("Hello " + name + ", you are " + age + "!")
    print(f"Hello {name}, you are {age}!")
    
greeting("Brian","22")
# Out:
# Hello Brian, you are 22!
# Hello Brian, you are 22!

# %%
def greeting(name,age=18):
    print(f"Hello {name}, you are {age}!")
    
greeting("Zoro")
# Out:
# Hello Zoro, you are 18!

# %%
def greeting(name,age=28):
    print("Hello " + name + ", you are " + str(age) + "!")
    print(f"Hello {name}, you are {age}!")

name = input("Enter your name: ")    
greeting(name,32)
greeting("Judith")
# Out:
# Hello teja, you are 32!
# Hello teja, you are 32!
# Hello Judith, you are 28!
# Hello Judith, you are 28!

# %%
def greeting(name, age=18):
    # Greets user with 'name' from 'input box' and 'age', if available, default age is used
    print('Hello '  +  name + ', you are ' + str(age) +'!')
    print(f'Hello {name}, you are {age}!')

name = input('Enter your name: ')
age = input('Enter your age: ')
greeting(name, 32)
# 1. Add new print statement - on a new line
#    which says 'We hear you like the color xxx! xxx is a string with color 
# 2. extend the function with another  input parameter 'color', that defaults to 'red'
# 3. Capture the color via an input box as variable:color 
# 4. Change the 'You are xx!' text to say 'you will be xx+1 years old next birthday 
#  adding 1 to the age
# 5. Capitalize first letter of the 'name', and rest are small caps 
# 6. Favorite color should be in lowercase
# Out:
# Hello teja, you are 32!
# Hello teja, you are 32!

# %%
def greeting(name, age=28, color = 'red'):
    #Greets user with 'name' from 'input box' and 'age' next year, if available, default age is used
    # also includes favorite color
    print('Hello '  +  name.capitalize() + ', you will be ' + str(age+1) +' next birthday!')
    print(f'Hello {name.capitalize()}, you will be {age+1} next birthday!')
    print(f'We hear you like the color {color.lower()}!')

name = input('Enter your name: ')
age = input('Enter your age: ')
color = input('Enter favorite color: ')
greeting(name, int(age), color)
# Out:
# Hello Teja , you will be 23 next birthday!
# Hello Teja , you will be 23 next birthday!
# We hear you like the color !

# %%
# argument - named notation
def greeting(name, age=28, color="red"):
 #Greets user with “name” from “input box” and “age”, if unavailable, default age is used   
   
   print(f"Hello {name.capitalize()}, you will be {age+1} next birthday!")
   print(f"We hear you like the color {color.lower()}!")

greeting(age=27, name="brian",color="Blue")
# Out:
# Hello Brian, you will be 28 next birthday!
# We hear you like the color blue!

# %%
# return - functions returning some data back to use else where in the code
def value_added_tax(amount):
    tax = amount * 0.25
    
print(value_added_tax(100))
# Out:
# None

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    return tax
    
price = value_added_tax(100)    
print( price, type(price))
# Out:
# 25.0 <class 'float'>

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    total_amount = amount * 1.25
    return amount, tax, total_amount
    
price = value_added_tax(100)    
print( price, type(price))
# Out:
# (100, 25.0, 125.0) <class 'tuple'>

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    total_amount = amount * 1.25
    return [amount, tax, total_amount]
    
price = value_added_tax(100)    
print(price, type(price))
# Out:
# [100, 25.0, 125.0] <class 'list'>

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    total_amount = amount * 1.25
    return [amount, tax, total_amount]
    
price = value_added_tax(100)    
print(price[1], type(price))
# Out:
# 25.0 <class 'list'>

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    total_amount = amount * 1.25
    return {amount, tax, total_amount}
    
price = value_added_tax(100)    
print(price, type(price))
# Out:
# {25.0, 100, 125.0} <class 'set'>

# %%
def value_added_tax(amount):
    tax = amount * 0.25
    total_amount = amount * 1.25
    return f"{amount}, {tax}, {total_amount}"
    
price = value_added_tax(100)    
print(price, type(price))
# Out:
# 100, 25.0, 125.0 <class 'str'>
