# %%
# lists
friends = ['Roger','White-Beard','Rocks','Dragon','Robin', 'Monkey', 'Robin']
print(friends)
print(friends[0], friends[1], "are best buddies.")
print(friends[-1], friends[-2], "are okay buddies.")
print(friends[1:4]) # 4 excluding
print(friends[:4])
print(friends[:])
print(len(friends))
print(friends.index('Robin')) # first occurrence
print(friends.count('Robin'))
# Out:
# ['Roger', 'White-Beard', 'Rocks', 'Dragon', 'Robin', 'Monkey', 'Robin']
# Roger White-Beard are best buddies.
# Robin Monkey are okay buddies.
# ['White-Beard', 'Rocks', 'Dragon']
# ['Roger', 'White-Beard', 'Rocks', 'Dragon']
# ['Roger', 'White-Beard', 'Rocks', 'Dragon', 'Robin', 'Monkey', 'Robin']
# 7
# 4
# 2

# %%
friends = ['Roger','White-Beard','Rocks','Dragon','Robin', 'Monkey', 'Robin']
cars = [911,130,328,535,740,308]
print(friends)
friends.sort()
print(friends)
friends.sort(reverse=True)
print(friends)
friends.reverse()
print(friends)
print(cars)
cars.sort()
print(cars)
# Out:
# ['Roger', 'White-Beard', 'Rocks', 'Dragon', 'Robin', 'Monkey', 'Robin']
# ['Dragon', 'Monkey', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard']
# ['White-Beard', 'Roger', 'Rocks', 'Robin', 'Robin', 'Monkey', 'Dragon']
# ['Dragon', 'Monkey', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard']
# [911, 130, 328, 535, 740, 308]
# [130, 308, 328, 535, 740, 911]

# %%
print(min(cars))
print(max(cars))
print(sum(cars))

print(min(friends))
print(max(friends))
# print(sum(friends)) # error
# Out:
# 130
# 911
# 2952
# Dragon
# White-Beard

# %%
friends.append('Teja')
print(friends)
friends.insert(1, 'Jesus')
print(friends)
# Out:
# ['Dragon', 'Monkey', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']
# ['Dragon', 'Jesus', 'Monkey', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']

# %%
friends[2] = 'New Graham'
print(friends)
# Out:
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']

# %%
# friends.extend(cars)
# print(friends)

# %%
cars.extend(friends)
print(cars)
# Out:
# [130, 308, 328, 535, 740, 911, 'Dragon', 'Jesus', 'New Graham', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']

# %%
print(friends)
friends.remove('Robin')
print(friends)
# Out:
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']

# %%
print(friends)
friends.pop(-1)
print(friends)
# Out:
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Rocks', 'Roger', 'White-Beard', 'Teja']
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Rocks', 'Roger', 'White-Beard']

# %%
popped = friends.pop(-1)
print(popped)
# Out:
# White-Beard

# %%
friends
# Out:
# ['Dragon', 'Jesus', 'New Graham', 'Robin', 'Rocks', 'Roger']

# %%
friends.clear()
friends
# Out:
# []

# %%
del friends
friends
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 del friends
#       2 friends
#
# NameError: name 'friends' is not defined

# %%
friends = ['John','Michael','Terry','Eric','Graham']
cars = [911,130,328,535,740,308]
del friends[2]
print(friends)
# Out:
# ['John', 'Michael', 'Eric', 'Graham']

# %%
friends = ['John','Michael','Terry','Eric','Graham']
print(friends)
# copy way 1
new_friends = friends
print(new_friends)
new_friends2 = new_friends[:]
print(new_friends2)
# Out:
# ['John', 'Michael', 'Terry', 'Eric', 'Graham']
# ['John', 'Michael', 'Terry', 'Eric', 'Graham']
# ['John', 'Michael', 'Terry', 'Eric', 'Graham']

# %%
# copy way 2
friends3 = friends.copy()
print(friends3)
# copy way 3
friends3 = list(friends)
print(friends3)
# Out:
# ['John', 'Michael', 'Terry', 'Eric', 'Graham']
# ['John', 'Michael', 'Terry', 'Eric', 'Graham']

# %%
sales_w1 = [7,3,42,19,15,35,9]
sales_w2 = [12,4,26,10,7,28]
sales = []
new_day = input('Enter #of lemonades for new day: ')
sales_w2.append(int(new_day))
#sales.extend(sales_w1)
#sales.extend(sales_w2)
sales = sales_w1 + sales_w2
# sales.sort()
# worst_day_prof = sales[0] * 1.5
# best_day_prof = sales[-1] * 1.5
worst_day_prof = min(sales) * 1.5
best_day_prof = max(sales) * 1.5
print(f'Worst day profit:Rs {worst_day_prof}')
print(f'Best day profit:Rs {best_day_prof}')
print(f'Combined profit:Rs {worst_day_prof + best_day_prof}')
# Out:
# Worst day profit:Rs 4.5
# Best day profit:Rs 63.0
# Combined profit:Rs 67.5

# %%
msg ='Welcome to Python 101: Split and Join'
csv = 'Eric,John,Michael,Terry,Graham'
friends_list = ['Eric','John','Michael','Terry','Graham']
print(list(msg))
# Out:
# ['W', 'e', 'l', 'c', 'o', 'm', 'e', ' ', 't', 'o', ' ', 'P', 'y', 't', 'h', 'o', 'n', ' ', '1', '0', '1', ':', ' ', 'S', 'p', 'l', 'i', 't', ' ', 'a', 'n', 'd', ' ', 'J', 'o', 'i', 'n']

# %%
msg ='Welcome  to  Python  101: Split  and Join'
csv = 'Eric,John,Michael,Terry,Graham'
friends_list = ['Eric','John','Michael','Terry','Graham']
print(msg.split())
print(msg.split(' '))
# Out:
# ['Welcome', 'to', 'Python', '101:', 'Split', 'and', 'Join']
# ['Welcome', '', 'to', '', 'Python', '', '101:', 'Split', '', 'and', 'Join']

# %%
print(type(msg.split(' ')))
# Out:
# <class 'list'>

# %%
csv = 'Eric,John,Michael,Terry,Graham'
print(csv.split(','))
# Out:
# ['Eric', 'John', 'Michael', 'Terry', 'Graham']

# %%
print(str(friends_list))
# Out:
# ['Eric', 'John', 'Michael', 'Terry', 'Graham']

# %%
type(friends_list)
# Out:
# list

# %%
print(''.join(friends_list))
print(' '.join(friends_list))
print(' - '.join(friends_list))
# Out:
# EricJohnMichaelTerryGraham
# Eric John Michael Terry Graham
# Eric - John - Michael - Terry - Graham

# %%
# when we split we turn something into a list and when we join we turn it into string

print(''.join(msg.split()))
# Out:
# WelcometoPython101:SplitandJoin

# %%
print(msg.replace(' ', ''))
# Out:
# WelcometoPython101:SplitandJoin

# %%
csv = 'Eric,John,Michael,Terry,Graham:TerryG;Brian'
friends_list = ['Exercise: fill me with names']
print(friends_list)
# From the list above fill a list(friends_list) properly
# with the names of all the friends. One per "slot"
# you may need to run same command several times
# use print() statements to work your way through the exercise
# Out:
# ['Exercise: fill me with names']

# %%
csv = 'Eric,John,Michael,Terry,Graham:TerryG;Brian'
print(','.join(csv.split(';')))
print(','.join(csv.split(';')).split(':'))
print(','.join(','.join(csv.split(';')).split(':')))
print((','.join(','.join(csv.split(';')).split(':'))).split(','))
# Out:
# Eric,John,Michael,Terry,Graham:TerryG,Brian
# ['Eric,John,Michael,Terry,Graham', 'TerryG,Brian']
# Eric,John,Michael,Terry,Graham,TerryG,Brian
# ['Eric', 'John', 'Michael', 'Terry', 'Graham', 'TerryG', 'Brian']

# %%
friends_list = (','.join(','.join(csv.split(';')).split(':'))).split(',')
print(friends_list)
# Out:
# ['Eric', 'John', 'Michael', 'Terry', 'Graham', 'TerryG', 'Brian']

# %%
print('replace', csv.replace(';',',').replace(':',',').split(','))
# Out:
# replace ['Eric', 'John', 'Michael', 'Terry', 'Graham', 'TerryG', 'Brian']
